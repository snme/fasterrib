# %%
import os
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
from skimage import exposure
from nilearn import plotting
# %matplotlib inline

# %%
img1 = nib.load("../data/stanford/niis/JC3d8df45-JC3d8df45.nii.gz")

# %%
img_data = img1.get_fdata()

# %%
img_data.shape
# Out:
# (512, 512, 212)

# %%
fig, ax = plt.subplots(figsize = (8,8), dpi=140)
ax.imshow(img_data[:, :, 150], cmap=plt.cm.gray)
ax.set_axis_off()
